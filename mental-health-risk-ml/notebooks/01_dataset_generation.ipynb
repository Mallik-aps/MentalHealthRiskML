# %% [markdown]
# # Starter Notebook
# Run the project scripts from here or the terminal.

# %%
# !python ../src/synthetic_data_generator.py --config ../config/config.yaml
